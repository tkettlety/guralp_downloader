# %%
from obspy import read

# %%
st = read('one_hour_request_for_20260101T010000/*.mseed')

# %%
st
# Out:
# 3 Trace(s) in Stream:
# OX.BOU5.1L.CHE | 2026-01-27T16:59:27.536000Z - 2026-01-27T16:59:41.368000Z | 250.0 Hz, 3459 samples
# OX.BOU5.1L.CHN | 2026-01-25T23:20:49.232000Z - 2026-01-25T23:21:04.124000Z | 250.0 Hz, 3724 samples
# OX.BOU5.1L.CHZ | 2026-01-26T08:27:37.156000Z - 2026-01-26T08:27:51.344000Z | 250.0 Hz, 3548 samples

# %%
st.plot()
