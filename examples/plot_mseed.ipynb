# %%
from pathlib import Path
from obspy import Stream, read

# %%
st = read("data/2026/OX/BOU5/CHZ.D/*")
st.merge()
print(st)
st.plot();
# Out:
# 1 Trace(s) in Stream:
# OX.BOU5.1L.CHZ | 2026-03-31T23:58:50.524000Z - 2026-04-04T00:01:06.144000Z | 250.0 Hz, 64833906 samples
