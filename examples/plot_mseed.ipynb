# %%
from obspy import Stream, read

# %%
st = read("data/2026/OX/BOU5/CH?.D/*")
st.merge()
print(st)
st.plot();
# Out:
# 3 Trace(s) in Stream:
# OX.BOU5.1L.CHE | 2026-04-01T11:58:48.764000Z - 2026-04-01T13:01:14.076000Z | 250.0 Hz, 936329 samples
# OX.BOU5.1L.CHN | 2026-04-01T11:58:54.692000Z - 2026-04-01T13:01:03.032000Z | 250.0 Hz, 932086 samples
# OX.BOU5.1L.CHZ | 2026-04-01T11:58:52.532000Z - 2026-04-01T13:00:58.800000Z | 250.0 Hz, 931568 samples
